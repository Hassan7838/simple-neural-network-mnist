# %% [markdown]
# <a href="https://colab.research.google.com/github/Hassan7838/simple-neural-network-mnist/blob/main/simple-neural-network-mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Simple Neural Network Development for Digit Classification on MNIST Dataset

# Import Libraries
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten

# %%
# Load and Preprocess mnist Dataset
(X_train, y_train),(X_test, y_test) = mnist.load_data()

# Normalize Pixel Values (0-255) --> (0-1)
X_train = X_train.astype("float32") / 255.0
X_test = X_test.astype("float32") / 255.0

# Flatten Images (28*28) --> (784) for Dense Layers
X_train = X_train.reshape((X_train.shape[0], 28*28))
X_test = X_test.reshape((X_test.shape[0], 28*28))

# One-hot encode labels (0-9 --> vector of size 10)
y_train = to_categorical(y_train,10)
y_test = to_categorical(y_test,10)

print("Training Data Shape : ",X_train.shape)
print("Testing Data Shape : ",X_test.shape)
# Out:
# Training Data Shape :  (60000, 784)
# Testing Data Shape :  (10000, 784)

# %%
# Building Model A (ReLU)

# Defining Model
model_relu = Sequential([
    Dense(128, activation='relu', input_shape=(784,)),
    Dense(64, activation='relu'),
    Dense(10, activation='softmax')
])

# Compiling Model
model_relu.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

# Train Model
history_relu = model_relu.fit(
    X_train, y_train,
    epochs=10,
    batch_size=32,
    validation_data=(X_test,y_test),
    verbose=1
)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.8795 - loss: 0.4129 - val_accuracy: 0.9598 - val_loss: 0.1281
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9666 - loss: 0.1069 - val_accuracy: 0.9723 - val_loss: 0.0895
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9780 - loss: 0.0705 - val_accuracy: 0.9768 - val_loss: 0.0747
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9835 - loss: 0.0527 - val_accuracy: 0.9690 - val_loss: 0.1053
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9876 - loss: 0.0402 - val_accuracy: 0.9722 - val_loss: 0.0893
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9900 - loss: 0.0296 - val_accuracy: 0.9771 - val_loss: 0.0826
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9910 - loss: 0.0285 - val_accuracy: 0.9801 - val_loss: 0.0720
# Epoch 8/10
# ...

# %%
# Building Model B (Sigmoid)

# Defining Model
model_sig = Sequential([
    Dense(128, activation='sigmoid', input_shape=(784,)),
    Dense(64, activation='sigmoid'),
    Dense(10, activation='softmax')
])

# Compiling Model
model_sig.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

# Train Model
history_sig = model_sig.fit(
    X_train, y_train,
    epochs=10,
    batch_size=32,
    validation_data=(X_test,y_test),
    verbose=1
)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7746 - loss: 0.8526 - val_accuracy: 0.9367 - val_loss: 0.2148
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9438 - loss: 0.1931 - val_accuracy: 0.9563 - val_loss: 0.1462
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9619 - loss: 0.1303 - val_accuracy: 0.9649 - val_loss: 0.1111
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9717 - loss: 0.0939 - val_accuracy: 0.9716 - val_loss: 0.0933
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9784 - loss: 0.0731 - val_accuracy: 0.9731 - val_loss: 0.0872
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9837 - loss: 0.0543 - val_accuracy: 0.9749 - val_loss: 0.0839
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9874 - loss: 0.0458 - val_accuracy: 0.9773 - val_loss: 0.0763
# Epoch 8/10
# ...

# %%
# Visual Comparison

# Function to plot accuracy and loss
def plot_history(history, title):
    plt.figure(figsize=(12,5))

    # Accuracy
    plt.subplot(1,2,1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title(f'{title} - Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()

    # Loss
    plt.subplot(1,2,2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title(f'{title} - Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.show()

# Plot for ReLU Model
plot_history(history_relu, "Model A (ReLU)")

# Plot for Sigmoid Model
plot_history(history_sig, "Model B (Sigmoid)")

# %%
# Conclusion: In general, ReLU is better than sigmoid but in our case as we have
# classification problem and sigmoid works better for classification problems so
# that's why sigmoid looks better than ReLU in our current case.
